# %%
import requests
import pymongo
import matplotlib.pyplot as plt
import numpy as np
import PIL
import datetime
import pandas as pd

from IPython.display import display, Image
from io import BytesIO
from glob import glob

# %matplotlib inline

# %%
def img2array(im):
    if im.mode != 'RGB':
        im = im.convert(mode='RGB')
    return np.fromstring(im.tostring(), dtype='uint8').reshape((im.size[1], im.size[0], 3))

# %%
client = pymongo.MongoClient('localhost', 27017)
images = client.surebet.images

# %%
male_first_names = pd.io.parsers.read_csv('data/dist.male.first', delim_whitespace=True, header=None)
female_first_names = pd.io.parsers.read_csv('data/dist.female.first', delim_whitespace=True, header=None)

last_names = pd.io.parsers.read_csv('data/dist.all.last', delim_whitespace=True, header=None)

# %%
for last_name in last_names[0][300:600]:
    for first_name in female_first_names[0][0:40]:
        
        r = requests.get('https://graph.facebook.com/%s.%s/picture?type=large' % 
                         (first_name, last_name))
        
        images.insert({"first_name": first_name,
                       "last_name": last_name,
                       "profile_picture": Binary(r.content),
                       "date": datetime.datetime.utcnow()})
# Out:
# ---------------------------------------------------------------------------
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-163-c7b98af164df> in <module>()
#       3
#       4         r = requests.get('https://graph.facebook.com/%s.%s/picture?type=large' %
# ----> 5                          (first_name, last_name))
#       6
#       7         images.insert({"first_name": first_name,
#
# /Library/Python/2.7/site-packages/requests/api.pyc in get(url, **kwargs)
#      63
#      64     kwargs.setdefault('allow_redirects', True)
# ---> 65     return request('get', url, **kwargs)
#      66
#      67
#
# /Library/Python/2.7/site-packages/requests/api.pyc in request(method, url, **kwargs)
#      47
#      48     session = sessions.Session()
# ---> 49     response = session.request(method=method, url=url, **kwargs)
#      50     # By explicitly closing the session, we avoid leaving sockets open which
# ...

# %%
first_name = 'autumn'
last_name = 'ellick'
r = requests.get('https://graph.facebook.com/%s.%s/picture?type=large' % (first_name, last_name))

img = PIL.Image.open(BytesIO(r.content))
x = img2array(img)
plt.imshow(x)

# %%
post = {"first_name": first_name,
        "last_name": last_name,
        "profile_picture": Binary(r.content),
        "date": datetime.datetime.utcnow()}

# %%
from bson.binary import Binary

# %%
images.insert(post)
# Out:
# ObjectId('54e4117fdf86c020017b5f17')

# %%
from bson import ObjectId

# %%
images.remove({"_id":ObjectId('54e2d6f2df86c018228cfb00')})
# Out:
# {u'n': 1, u'ok': 1}

# %%
r.headers
# Out:
# {'content-length': '20093', 'expires': 'Tue, 03 Mar 2015 06:37:16 GMT', 'last-modified': 'Tue, 05 Nov 2013 03:27:44 GMT', 'connection': 'keep-alive', 'cache-control': 'no-transform, max-age=1209600', 'date': 'Tue, 17 Feb 2015 06:37:16 GMT', 'access-control-allow-origin': '*', 'content-type': 'image/jpeg', 'timing-allow-origin': '*'}

# %%
import pymongo

# %%
import bson

# %%
Binary(r.content)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-97-61131213ecfd> in <module>()
# ----> 1 Binary(r.content).encode()
#
# UnicodeDecodeError: 'ascii' codec can't decode byte 0xff in position 0: ordinal not in range(128)

# %%
posts.find({"author": "Mike"})

# %%
y = [x['profile_picture'] for x in images.find({"first_name": "MATT", "last_name": "JOHNSON"})]

img = PIL.Image.open(BytesIO(y[0]))
x = img2array(img)
plt.imshow(x)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-183-024d176e7b67> in <module>()
#       1 y = [x['profile_picture'] for x in images.find({"first_name": "MATT", "last_name": "JOHNSON"})]
#       2
# ----> 3 img = PIL.Image.open(BytesIO(y[0]))
#       4 x = img2array(img)
#       5 plt.imshow(x)
#
# IndexError: list index out of range
