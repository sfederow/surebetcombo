# %%
import requests
import pymongo
import matplotlib.pyplot as plt
import numpy as np
import PIL
import datetime
import pandas as pd

from IPython.display import display, Image
from io import BytesIO
from glob import glob

# %matplotlib inline

# %%
def img2array(im):
    if im.mode != 'RGB':
        im = im.convert(mode='RGB')
    return np.fromstring(im.tostring(), dtype='uint8').reshape((im.size[1], im.size[0], 3))

# %%
client = pymongo.MongoClient('localhost', 27017)
images = client.surebet.images

# %%
male_first_names = pd.io.parsers.read_csv('dist.male.first', delim_whitespace=True, header=None)
female_first_names = pd.io.parsers.read_csv('dist.female.first', delim_whitespace=True, header=None)

last_names = pd.io.parsers.read_csv('dist.all.last', delim_whitespace=True, header=None)[0]

# %%
for last_name in last_names:
    
    x#print last_name

# %%
first_name = 'stephen'
last_name = 'federowicz.5'
r = requests.get('https://graph.facebook.com/%s.%s/picture?type=large' % (first_name, last_name))

# %%
post = {"first_name": first_name,
        "last_name": last_name,
        "profile_picture": Binary(r.content),
        "date": datetime.datetime.utcnow()}

# %%
from bson.binary import Binary

# %%
images.insert(post)
# Out:
# ObjectId('54e4117fdf86c020017b5f17')

# %%
img = PIL.Image.open(BytesIO(r.content))
x = img2array(img)
plt.imshow(x)

# %%
from bson import ObjectId

# %%
images.remove({"_id":ObjectId('54e2d6f2df86c018228cfb00')})
# Out:
# {u'n': 1, u'ok': 1}

# %%
r.headers
# Out:
# {'content-length': '20093', 'expires': 'Tue, 03 Mar 2015 06:37:16 GMT', 'last-modified': 'Tue, 05 Nov 2013 03:27:44 GMT', 'connection': 'keep-alive', 'cache-control': 'no-transform, max-age=1209600', 'date': 'Tue, 17 Feb 2015 06:37:16 GMT', 'access-control-allow-origin': '*', 'content-type': 'image/jpeg', 'timing-allow-origin': '*'}

# %%
import pymongo

# %%
import bson

# %%
Binary(r.content)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-97-61131213ecfd> in <module>()
# ----> 1 Binary(r.content).encode()
#
# UnicodeDecodeError: 'ascii' codec can't decode byte 0xff in position 0: ordinal not in range(128)

# %%
[x for x in images.find()]
# Out:
# [{u'_id': ObjectId('54e2e21cdf86c020017b5f16'),
#   u'date': datetime.datetime(2015, 2, 17, 6, 39, 23, 75000),
#   u'first_name': u'stephen',
#   u'last_name': u'federowicz.5',
# ...
